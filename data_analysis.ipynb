# %%
# STEP 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# STEP 2: Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# STEP 3: Load CSV file from Drive
file_path = '/content/drive/MyDrive/colab_files/enriched_jora_jobs_10000.csv'  #
df = pd.read_csv(file_path)

# STEP 4: Basic Exploration
print("First 5 rows of the dataset:")
print(df.head())

print("\n Dataset shape (rows, columns):", df.shape)

print("\n Column data types and non-null counts:")
print(df.info())

print("\n Summary statistics (numerical features):")
print(df.describe())

print("\n Missing values per column:")
print(df.isnull().sum())

# STEP 5: Optional Cleaning Example
# Fill missing values (customize as needed)
# df.fillna('Unknown', inplace=True)  # or
# df.dropna(inplace=True)

# STEP 6: Basic Analysis Examples
# Replace column names based on your actual dataset

# Example: Count unique values in a categorical column
# print(df['Gender'].value_counts())

# Example: Group by and calculate mean (e.g., Avg purchase per region)
# print(df.groupby('Region')['Purchase_Amount'].mean())

# Correlation matrix for numerical features
print("\n Correlation Matrix:")
numeric_df = df.select_dtypes(include=['number'])
print(numeric_df.corr())

# STEP 7: Visualizations

# Histogram of a numerical column
# df['Age'].hist(bins=30)
# plt.title('Distribution of Age')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.show()

# Bar plot of a categorical column
# df['Gender'].value_counts().plot(kind='bar')
# plt.title('Gender Distribution')
# plt.xlabel('Gender')
# plt.ylabel('Count')
# plt.show()
# STEP 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# STEP 2: Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# STEP 3: Load CSV file from Drive
file_path = '/content/drive/MyDrive/colab_files/enriched_jora_jobs_10000.csv'  #
df = pd.read_csv(file_path)

# STEP 4: Basic Exploration
print(" First 5 rows of the dataset:")
print(df.head())

print("\n Dataset shape (rows, columns):", df.shape)

print("\n Column data types and non-null counts:")
print(df.info())

print("\n Summary statistics (numerical features):")
print(df.describe())

print("\n Missing values per column:")
print(df.isnull().sum())

# STEP 5: Optional Cleaning Example
# Fill missing values (customize as needed)
# df.fillna('Unknown', inplace=True)  # or
# df.dropna(inplace=True)

# STEP 6: Basic Analysis Examples
# Replace column names based on your actual dataset

# Example: Count unique values in a categorical column
# print(df['Gender'].value_counts())

# Example: Group by and calculate mean (e.g., Avg purchase per region)
# print(df.groupby('Region')['Purchase_Amount'].mean())

# Correlation matrix for numerical features
print("\n Correlation Matrix:")
numeric_df = df.select_dtypes(include=['number'])
print(numeric_df.corr())

# STEP 7: Visualizations

# Histogram of a numerical column
# df['Age'].hist(bins=30)
# plt.title('Distribution of Age')
# plt.xlabel('Age')
# plt.ylabel('Frequency')
# plt.show()

# Bar plot of a categorical column
# df['Gender'].value_counts().plot(kind='bar')
# plt.title('Gender Distribution')
# plt.xlabel('Gender')
# plt.ylabel('Count')
# plt.show()

numeric_df = df.select_dtypes(include=['number'])
print("Numeric columns found:", numeric_df.columns.tolist())
print("Shape of numeric_df:", numeric_df.shape)

# Attempt to convert all columns to numeric where possible
df_numeric_fixed = df.copy()

for col in df.columns:
    df_numeric_fixed[col] = pd.to_numeric(df[col], errors='coerce')

# Now re-select numeric columns
numeric_df = df_numeric_fixed.select_dtypes(include=['number'])
print("Fixed numeric columns:", numeric_df.columns.tolist())

# Heatmap of correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Numerical Columns Only)')
plt.show()

# STEP 8: Save cleaned/modified dataset back to Google Drive (optional)
# df.to_csv('/content/drive/MyDrive/colab_files/customer_data_cleaned.csv', index=False)
# Attempt to convert all columns to numeric where possible
df_numeric_fixed = df.copy()

for col in df.columns:
    df_numeric_fixed[col] = pd.to_numeric(df[col], errors='coerce')

# Now re-select numeric columns
numeric_df = df_numeric_fixed.select_dtypes(include=['number'])
print("Fixed numeric columns:", numeric_df.columns.tolist())

# Heatmap of correlation matrix
plt.figure(figsize=(10,8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap (Numerical Columns Only)')
plt.show()

# STEP 8: Save cleaned/modified dataset back to Google Drive (optional)
# df.to_csv('/content/drive/MyDrive/colab_files/customer_data_cleaned.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# First 5 rows of the dataset:
#                                         Title                  Company  \
# 0       Entry- Level IT Support / IT Graduate          Teekay Shipping
# 1             IT Helpdesk Support (Part-Time)              Nutrimetics
# 2  IT Support & Website Content Administrator    Holidays of Australia
# 3        IT Traineeship - Call Centre Support             WorkVentures
# 4           Entry-level IT Service Technician  Centorrino Technologies
#
#           City State                                        Description  \
# 0   Sydney CBD   NSW  Provide first-line IT support for hardware, so...
# 1  Gladesville   NSW  Provide Level 1 & 2 IT support for hardware/so...
# 2     Adelaide    SA  Hybrid role combining IT support and website c...
# 3   Alexandria   NSW  Entry-level IT helpdesk support role with on-t...
# ...
